# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\hemen\Downloads\Sample data.xlsx")

# %%
df.isnull().sum()
# Out:
# Segment                 0
# Country                 0
# Product                 0
# Discount Band          53
# Units Sold              0
# Manufacturing Price     0
# Sale Price              0
# Gross Sales             0
# Discounts               0
#  Sales                  0
# COGS                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64

# %%
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.427859           108.602612  136.775515  2.542623e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       800.320000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        647 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %% [markdown]
# # HANDLING NULL VALUES

# %%
(df['Discount Band']).isnull().value_counts()
# Out:
# Discount Band
# False    647
# True      53
# Name: count, dtype: int64

# %%
df['Discount Band'].fillna('Unknown', inplace = True)
# Out:
# C:\Users\hemen\AppData\Local\Temp\ipykernel_3500\316646924.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Discount Band'].fillna('Unknown', inplace = True)

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# dtype: int64

# %%
 df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government  Germany  Carretera       Unknown      1513.0
# 1  Government  Germany      Paseo       Unknown      1006.0
# 2  Government   Canada      Paseo       Unknown      1725.0
# 3  Government  Germany      Paseo       Unknown      1513.0
# 4  Government  Germany       Velo       Unknown      1006.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3         350     529550.0        0.0  529550.0
# 1                   10         350     352100.0        0.0  352100.0
# 2                   10         350     603750.0        0.0  603750.0
# 3                   10         350     529550.0        0.0  529550.0
# 4                  120         350     352100.0        0.0  352100.0
#
#        COGS    Profit       Date  Month Number Month Name  Year
# 0  393380.0  136170.0 2014-12-01            12   December  2014
# ...

# %%
df.tail()
# Out:
#               Segment                   Country Product Discount Band  \
# 695         Midmarket                    Canada   Paseo          High
# 696         Midmarket                    Canada   Paseo          High
# 697        Enterprise                   Germany   Paseo          High
# 698         Midmarket                   Germany   Paseo          High
# 699  Channel Partners  United States of America   Paseo          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 695      1614.0                   10          15      24210.0    3631.50
# 696      2559.0                   10          15      38385.0    5757.75
# 697      1085.0                   10         125     135625.0   20343.75
# 698      1175.0                   10          15      17625.0    2643.75
# 699       914.0                   10          12      10968.0    1645.20
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
total_sales = df[' Sales'].sum()
total_profit = df['Profit'].sum()
profit_margin = total_profit/total_sales

# %%
total_sales
# Out:
# np.float64(118726350.25999999)

# %%
total_profit
# Out:
# np.float64(16893702.26)

# %%
profit_margin
# Out:
# np.float64(0.14229109395685388)

# %% [markdown]
# # SALE BY MONTH

# %%
df.groupby('Year')[[' Sales','Profit']].sum()
df.groupby('Month Name')[[' Sales','Profit']].sum()
# Out:
#                   Sales      Profit
# Month Name
# April        6964775.07   929984.57
# August       5864622.42   791066.42
# December    17367228.98  2717329.98
# February     7297531.39  1148547.39
# January      6607761.68   814028.68
# July         8102920.18   923865.68
# June         9518893.82  1473753.82
# March        5586859.87   669866.87
# May          6210211.06   828640.06
# November    12651417.50  1370102.50
# October     21671431.02  3439781.02
# September   10882697.27  1786735.27

# %%
plt.figure(figsize=(10,3))
df.groupby('Month Name')['Profit'].sum().plot()
plt.title('Profit over the Year')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.show()

# %%
month_order = ['January','February','March','April','May','June','July','August','September','October','November','December']
plt.figure(figsize=(10,3))
(df.groupby('Month Name')['Profit'].sum().reindex(month_order).plot())
plt.title('Profit over the Year')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# # PROFIT BY PRODUCT

# %%
df.groupby('Product')[[' Sales','Profit','Units Sold']].sum().sort_values(' Sales', ascending=False)
# Out:
#                   Sales       Profit  Units Sold
# Product
# Paseo      3.301114e+07  4797437.950    338239.5
# VTT        2.051192e+07  3034608.020    168783.0
# Velo       1.825006e+07  2305992.465    162424.5
# Amarilla   1.774712e+07  2814104.060    155315.0
# Montana    1.539080e+07  2114754.880    154198.0
# Carretera  1.381531e+07  1826804.885    146846.0

# %%
plt.figure(figsize=(10,3))
df.groupby('Product')[' Sales'].sum().plot(kind='bar')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel(' Sales (Millions USD)')
plt.show()

# %% [markdown]
# # SALE AND PROFIT BY COUNTRY

# %%
df.groupby('Country')[[' Sales','Profit']].sum()
# Out:
#                                  Sales       Profit
# Country
# Canada                    2.488765e+07  3529228.885
# France                    2.435417e+07  3781020.780
# Germany                   2.350534e+07  3680388.820
# Mexico                    2.094935e+07  2907523.110
# United States of America  2.502983e+07  2995540.665

# %%
plt.figure(figsize=(10,3))
df.groupby('Country')[' Sales'].sum().plot(kind='bar')
plt.title('Total Sales by Country')
plt.xlabel('Country')
plt.ylabel(' Sales (Millions USD)')
plt.show()

# %%
df.groupby('Discount Band')[[' Sales','Profit']].mean()
# Out:
#                        Sales        Profit
# Discount Band
# High           152540.762143  13832.109082
# Low            216436.116875  38680.360625
# Medium         160249.714194  23055.879483
# Unknown        149880.264151  32763.301887

# %% [markdown]
# # PROFIT ANALYSIS

# %%
df['Profit Margin'] = df['Profit'] / df[' Sales']
df.groupby('Product')['Profit Margin'].mean()
# Out:
# Product
# Amarilla     0.289925
# Carretera    0.295230
# Montana      0.272094
# Paseo        0.285508
# VTT          0.263765
# Velo         0.264858
# Name: Profit Margin, dtype: float64

# %% [markdown]
# # LOSS ANALYSIS

# %%
df[df['Profit'] < 0]
# Out:
#         Segment                   Country    Product Discount Band  \
# 392  Enterprise  United States of America    Montana        Medium
# 397  Enterprise                   Germany       Velo        Medium
# 398  Enterprise  United States of America       Velo        Medium
# 399  Enterprise                    France       Velo        Medium
# 406  Enterprise                   Germany  Carretera        Medium
# 408  Enterprise                    Canada       Velo        Medium
# 409  Enterprise  United States of America       Velo        Medium
# 415  Enterprise                    France   Amarilla        Medium
# 427  Enterprise                   Germany    Montana        Medium
# 429  Enterprise                   Germany       Velo        Medium
# 434  Enterprise                    Canada   Amarilla        Medium
# 435  Enterprise                   Germany   Amarilla        Medium
# 437  Enterprise                    Mexico  Carretera        Medium
# ...

# %%
sns.boxplot(x='Segment', y='Profit', data=df)
# Out:
# <Axes: xlabel='Segment', ylabel='Profit'>

# %%
numeric_df = df.select_dtypes(include='number')

# %%
corr = numeric_df.corr()
# +1 → strong positive relationship
# 0 → no relationship
# –1 → strong negative relationship

# %%
plt.figure(figsize=(8,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                   Germany  Carretera       Unknown
# 1          Government                   Germany      Paseo       Unknown
# 2          Government                    Canada      Paseo       Unknown
# 3          Government                   Germany      Paseo       Unknown
# 4          Government                   Germany       Velo       Unknown
# ..                ...                       ...        ...           ...
# 695         Midmarket                    Canada      Paseo          High
# 696         Midmarket                    Canada      Paseo          High
# 697        Enterprise                   Germany      Paseo          High
# 698         Midmarket                   Germany      Paseo          High
# 699  Channel Partners  United States of America      Paseo          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# Profit Margin          0
# dtype: int64

# %%
clean_df = df

# %%
clean_df.to_excel("cleaned_dataset.xlsx", index=False)
